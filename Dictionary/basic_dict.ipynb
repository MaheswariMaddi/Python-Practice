# %%
Phn_No={
"Ram":4567,
"Mahi":10987,
"Siva":34214,
}
print(Phn_No)
d2=dict({'raju':8970})
print(type(d2),d2)
d3=dict([("Mahi",45)])
print(d3)
Phn_No["Ram"]={"home":1111,"Work":2222}
print(Phn_No["Ram"]["Work"])
Phn_No["Raju"]=1234
print(Phn_No["Mahi"])
#get()
d={"Name":"Siva","Age":45}
print(d.get("Name"))
print(d.get("salary"))
print(d.get("id"),"Not found")#get() if value not found it returns None by deafault
d.update({"Name":"Ravi","Ram":4567,"Mahi":10987,"Siva":34214})
#we can add multiple values to dict by using update method.
d['Num']=3,4,56,
print(d)
A={"Name":"Siva","Age":45}
del A["Name"]
del A["Age"]
print(A)
#pop()
p={"Name":"Siva","Age":45}
r=p.pop("Age")
print(r,p)
#popitem
d1={"brand":"Ford","Model":234,"year":2022}
s=d1.popitem()
print(s,d1)
d1.clear()
print(d1)

for i in Phn_No:
   print(i)
   print(Phn_No[i])
for i in Phn_No.values():
   print(i)   
for i in Phn_No.items():
   print(i)   
#M={"Name":"Raju",{1,2,3}:"scores"}
#print(type({1,2,3}))
#print(M[1,2,3])
f={"A":123,1:"Apple","b":75}
s={}
print(len(f))
print("Any method",any(f))
print(all(f))
