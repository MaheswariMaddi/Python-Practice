# %%
# R - 120 encoding - binary - while storing into memory
# binary - 10 - R decoding - while retrieving from memory

# a = "Ram Mallikarjun" 
# print(a)

# [R][a][M][][][][]
# 1000

# 1000 - 1001 - 1002 - 1003
# 1004 - 1005 - 1006 - 1007
# a - 1000
# a[0] - 1000+ (0*4) - 1000
# a[1] - 1000+ (1*4) - 1004

# print(a[5:100:1])
# a = a[0] + 'A' + a[2:]
# print(a)
# print(2 * a)
# print(a[:10])
# print(a[1:5])
# print("-ve", a[-1:-5:-1])

# +ve
# print(a[::]) #last char index
# print(a[:10]) #start char index
# 1- 5 +1
# 3 -1  -1

# -ve
# print(a[-1]) #last char index
# print(a[:-10]) #start char index

# -5 - -1 +1
# -3 - -7  -1

# print('ju' in a)




# str = "dasfd"
# a = "DFsaf"

# print("\\2: ")

# print(f"{a} = {str}")

# print(a.upper())


# a = "Ram"
# print(a)
# print(a.center(15, '$'))


a = "This is a python tutorial from java t point"

print(a.count("i"))

print(a.endswith("i", 2, 6))

print(a.find("i", 3, 6))

# print(a.index("i", 3, 5))

print(a.isalnum())
print(a.isalpha())
print(a.isnumeric())
# a = "lage"
# print("is",a.isidentifier())
print(a.isspace())

# a = "This Is A Title"
# print(a.istitle())

print(a)

a = ['1', '2','5']

print("$".join(a))
# Out:
# 4
# True
# 5
# False
# False
# False
# False
# This is a python tutorial from java t point
# 1$2$5
